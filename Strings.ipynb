# %% [markdown]
# # Strings are Sequence of charcters
# # In python specifically, strings are a sequence of Uniconde Charcters
# ## . Creating Strings
# ## . Accessing Strings
# ## . Adding Chars to Strings
# ## . Editing Strings
# ## . Deleting Strings
# ## . Operatings on Strings
# ## . String Functions

# %% [markdown]
# # creating

# %%
s = 'hello'
s = "hello"
# for multiline strings
s = """Hello"""
s = str('hello')
print(s)
# Out:
# hello

# %%
"it's raining outside"
# Out:
# "it's raining outside"

# %%
# Indexing

s = 'Hello World'

print(s[0])
# Out:
# H

# %%
#Negative indexing
s = "Hello World"
print(s[-3])
# Out:
# r

# %%
# Slicing
s = 'Hello World'
#print(s[0:5])
print(s[0:6:2])
# Out:
# Hlo

# %%
print(s[6:0:-1])
# Out:
# W olle

# %%
print(s[::-1])
# Out:
# dlroW olleH

# %%
# negative indexing
s = 'Hello World'
print(s[-5:-1])
# whenever used to negative index the first number is greater
print(s[-1:-6:-1])
# Out:
# Worl
# dlroW

# %%
s = 'hello world'
s[0] = 'H'
# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 s = 'hello world'
# ----> 2 s[0] = 'H'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 3
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# # Opreatinal on String
#
# ## . Arthmetic Opreations
# ## .Relations Operations
# ## .Logical Operations
# ## .Loop on Strings
# ## .Memberships Opreations

# %%
print('Delhi'+ ' ' + 'mumbai')
# Out:
# Delhi mumbai

# %%
print('delhi'*5)
# Out:
# delhidelhidelhidelhidelhi

# %%
print('*'*50)
# Out:
# **************************************************

# %%
'delhi' == 'mumbai'
'delhi' == 'delhi'
# Out:
# True

# %%
'mumbai'> 'pune'
# lexiographically
# Out:
# False

# %%
"Pune" > 'pune'
# Out:
# False

# %%
# Logicaly
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
''  and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
not ''
not 'Delhi'
# Out:
# False

# %%
for i in 'Hello':
    print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in 'delhi':
    print('pune')
# Out:
# pune
# pune
# pune
# pune
# pune

# %%
# membership
'D' in 'Delhi'
# Out:
# True

# %% [markdown]
# # Common Functions
# ## . len
# ## .max
# ## .min
# ## .sorted
# ## .

# %%
len("hello World")
# Out:
# 11

# %%
max("Hello Word")
# Out:
# 'r'

# %%
min("Hello world")
# Out:
# ' '

# %%
sorted("hello world",reverse = True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s = "hello world"
s.capitalize()
# Out:
# 'Hello world'

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
"Hello World".lower()
# Out:
# 'hello world'

# %%
"Hello World".swapcase()
# Out:
# 'hELLO wORLD'

# %%
"my name is nitish".count('i')
# Out:
# 3

# %%
"my name is nitish".find('is')
# Out:
# 8

# %%
"my name is nitish".find('x')
# Out:
# -1

# %%
"my name is nitish".index('is')
# Out:
# 8

# %%
"my name is nitish".index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 "my name is nitish".index('x')
#
# ValueError: substring not found

# %% [markdown]
# # endswith/ startswith

# %%
"my name is nitish".endswith('sh')
"my name is nitish".endswith('sho')
# Out:
# False

# %%
"my name is nitish".startswith('sh')
"my name is nitish".startswith('my')
# Out:
# True

# %% [markdown]
# # Format

# %%
name = 'nitsh'
gender = 'male'

'hi my is {} and i am is {}'.format(name,gender)
# Out:
# 'hi my is nitsh and i am is male'

# %%
 # split/join
'hi my name is tanish'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'tanish']

# %%
" ".join(['hi', 'my', 'name', 'is', 'tanish'])
# Out:
# 'hi my name is tanish'

# %%
#REplace
'hi my name is tanish'.replace('tanish', 'sonu')
# Out:
# 'hi my name is sonu'

# %%
# strip

'tanish                              '.strip()
# Out:
# 'tanish'

# %%
s = input('enter the string')
L = []
for i in s.split():
    L.append(i[0].upper() + i[1:].lower())

print(L)
# Out:
# enter the string nside a table, a column often contains many duplicate values; and sometimes you only want to list the different (distinct) values.
# ['Nside', 'A', 'Table,', 'A', 'Column', 'Often', 'Contains', 'Many', 'Duplicate', 'Values;', 'And', 'Sometimes', 'You', 'Only', 'Want', 'To', 'List', 'The', 'Different', '(distinct)', 'Values.']

# %%
s = input('enter the string')
counter = 0
for i in s:
    counter += 1
print('lenght of string is', counter)
# Out:
# enter the string pawan
# lenght of string is 5

# %%
s = input('enter the email')
pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email tanish123597@yahoo.com
# tanish123597

# %%
s = input('enter the email')
term = input('what would like to search for')

counter = 0

for i in s:
    if i == term:
        counter += 1
print('frequence', counter)
# Out:
# enter the email hi how are you
# what would like to search for o
# frequence 2

# %%
# write a program which can remove a particular charcter from a string.

s = input("enter the string")
term = input("what would like to remove")

result = ''
for i in s:
    if i != term:          
        result += i 

print('remove the chaecters',result)
# Out:
# enter the string tanish
# what would like to remove s
# remove the chaecters tanih

# %%
s = input("enter the string")
#palindrome
flag = True
for i in range(0,len(s)//2):
    if s[i] != s[len(s)-i-1]:
        flag = False
        print('not a palindrom')
        break
if flag:
    print('Palindrom')
# Out:
# enter the string abba
# Palindrom

# %%
s = input("enter the string")
L = []
temp = '' 
for i in s:
    if i !=  ' ':
        temp += i
    else:
        L.append(temp)
        temp =''
L.append(temp)
print(L)
# Out:
# enter the string hi how are you
# ['hi', 'how', 'are', 'you']

# %%
s = input("enter the string")
L = []
for i in s.split():
    L.append(i[0].upper() + i[1:].lower())

print(" ".join(L) )
# Out:
# enter the string my namE iS tanisH
# My Name Is Tanish
